# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
import statsmodels.api as sm

# Reading data
data = pd.read_csv(r'C:\Users\User\Desktop\Test_Assignment.csv') 
df = pd.DataFrame(data, columns= ['ClientCode','Age', 'payroll', 'Income', 'Tenure', 'Gender', 'numCC_act', 'numFastConsLoan','PurchasedCC', 'TotalNewLimit'])

# Converting NaN to Zeros
df['Income'] = df['Income'].fillna(0)

# Converting string array to float array
income = []
for i in df['Income']:
    if type(i) is str:
        income_Str = i.replace(',', '')
        i = float(income_Str)
    income.append(i)

# Plotting
plt.figure(1)
plt.scatter(df['Age'], df['TotalNewLimit'])
plt.title('Age')
plt.figure(2)
plt.scatter(df['payroll'], df['TotalNewLimit'])
plt.title('payroll')        
plt.figure(3)
plt.scatter(income, df['TotalNewLimit'])
plt.title('Income')
plt.figure(4)
plt.scatter(df['Tenure'], df['TotalNewLimit'])
plt.title('Tenure')
plt.figure(5)
plt.scatter(df['numCC_act'], df['TotalNewLimit'])
plt.title('numCC_act')
plt.figure(6)
plt.scatter(df['numFastConsLoan'], df['TotalNewLimit'])
plt.title('numFastConsLoan')
plt.show()

# Converting horizontal list to vertical array
def listToArray(*args): 
    for ar in args:
        x = np.asarray(ar)
        return x.reshape(10000,1)
        
listToArray(df['Age'], df['Tenure'], income, df['numFastConsLoan'])

X = np.hstack((X1,X2,X3,X4)) # adding columns
Y = df['TotalNewLimit']

# with sklearn
regr = linear_model.LinearRegression()
regr.fit(X, Y)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)
# Out:
# Intercept:
#  237.3179476486223
# Coefficients:
#  [-1.56348030e+00  3.90813357e+01  1.74831850e-01  2.94025300e+02]
